# %% [markdown]
# # <font color = red> Tarea
# **Esta tarea incluye el ejercicio dejado en la clase anterior**
# ![aaaaa.png](attachment:aaaaa.png)
# Además use el método de estratificación donde se divide en B estratos, visto la clase pasada y compare el resultado con los métodos anteriores cuando se toman $2,4,6,10$ estratos respectivamente, concluya.

# %%
import numpy as np 
import random
from functools import reduce
import time
import matplotlib.pyplot as plt
import scipy.stats as st 
import pandas as pd

# %%
f_x=lambda x: 3*x**2/2 if x>=-1 and x<=1 else 0 
x1 = lambda x: x**(1/3) if x>=0 else -(-x)**(1/3)
x2 = lambda u: x1(2*u-1)
N= 10**5
u1= np.random.uniform(0,1,N)
f_u1= list(map(lambda x:x2(x), u1))
f_u1 = np.asarray(f_u1)
y, x, p= plt.hist(f_u1, bins= 100, density=True)
y2= list(map(lambda x: f_x(x), x))
plt.plot(x,y2)
plt.show()

# %% [markdown]
# ## a) Montecarlo Crudo

# %%
N=10**5
a= np.random.uniform(0,1,N)
muestras= x1(a)
print(muestras.mean())


print(muestras.max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-64ccccbfbaa9> in <module>
#       1 N=10**5
#       2 a= np.random.uniform(0,1,N)
# ----> 3 muestras= x1(a)
#       4 print(muestras.mean())
#       5
#
# <ipython-input-5-1f2b50c6a894> in <lambda>(x)
#       1 f_x=lambda x: 3*x**2/2 if x>=-1 and x<=1 else 0
# ----> 2 x1 = lambda x: x**(1/3) if x>=0 else -(-x)**(1/3)
#       3 x2 = lambda u: x1(2*u-1)
#       4 N= 10**5
#       5 u1= np.random.uniform(0,1,N)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# ## b) Muestreo estratificado

# %%
np.random.seed(100)
r1= np.random.uniform(0,.6,3)
r2= np.random.uniform(.6,.9,3)
r3= np.random.uniform(.9,1,4)

r=[r1,r2,r3]

w1 = (3/10)/.6
w2 = (3/10)/.3
w3 = (4/10)/.1

w=[w1,w2,w3]


muestras2= list(map(lambda x,a: np.asarray([x2(i) for i in x])/a,r,w))
media = np.concatenate(muestras2).mean()
media
# Out:
# -0.16346936901447945
